# %% [markdown]
# ### 🚀 **RappiBoost: Business Case de Otimização de Conversões para Restaurante Parceiro**
#
# **Visão Geral**: *RappiBoost* é um business case desenvolvido para melhorar a eficiência e as conversões dos restaurantes parceiros na plataforma Rappi. Utilizando técnicas avançadas de análise de dados e BI, o projeto visa identificar pontos de ruptura no funil de conversão e propor estratégias práticas para aumentar a taxa de conversão e a satisfação dos usuários.
#
# ## **Objetivo** 🎯
#
# O objetivo principal deste business case é otimizar o desempenho dos restaurantes parceiros da Rappi, e buscar aumentar a taxa de conversão das etapas críticas do funil, desde a visualização de produtos até a confirmação de pedidos.
#
# ## **Arquivos** 📂
#
# O projeto consiste em diversos arquivos de dados que detalham sessões, conversões e outras métricas relevantes:
#
# 1. **Visão GERAL RESTAURANTES - Sessões.csv**: Dados semanais sobre sessões e atividades dos usuários nos restaurantes.
# 2. **Visão GERAL RESTAURANTES - Conversões.csv**: Taxas de conversão semanais para os restaurantes.
# 3. **Visão CARTEIRA - Sessões.csv**: Dados de sessões específicos para a carteira de restaurantes.
# 4. **Visão CARTEIRA - Conversões.csv**: Taxas de conversão específicas para a carteira de restaurantes.
# 5. **Sessões_Conversão - Usuários 1.csv**: Dados de sessões e conversões para um grupo específico de usuários.
# 6. **Sessões_Conversão - Usuários 2.csv**: Dados de sessões e conversões para outro grupo específico de usuários.
# 7. **LEIA-ME.csv**: Explicações sobre as colunas e perguntas a serem respondidas no business case.
#
# ## **Análises Realizadas** 🔍
#
# ### Comportamento dos Usuários
# Análise comparativa do comportamento dos dois grupos de usuários para identificar padrões e oportunidades de melhoria.
#
# ### Funil de Conversão
# Identificação de pontos de ruptura no funil de conversão, com destaque para as etapas que apresentam maiores quedas nas taxas de conversão.
#
# ### Propostas de Melhoria
# Propostas específicas para melhorar a performance da carteira de restaurantes, baseadas nos insights obtidos a partir da visão geral dos restaurantes.
#
# ## **Perguntas a serem Respondidas** ❓
#
# 1. **Quais conclusões é possível chegar sobre o funil de conversões da carteira?**
#    - - A conversão média (SST-OPC) da carteira é de 17% e da vertical restaurantes é de 26%. Ou seja, há uma possibilidade de melhoria de até 9% da conversão mensal.
#    - Há possibilidades de crescimento nas etapas:
#     - "Proceder ao Checkout (PTC)" e "Pedido Solitidado (OP)" de até 17%.
#     - "Pedido Solitidado (OP)" e "Pedidos Confirmados (OPC)" de até 10%.
#     - "Visualizações de Produto (VPD)" e "Adições ao Carrinho (ATC)" de até 9%.
#
# 2. **Existe algum insight do funil de conversão com as input metrics?**
#    - A disponibilidade de lojas na carteira de restaurantes é consistentemente alta (98%) ao longo das semanas analisadas, e acima da média da vertical restaurante. Isso indica que as lojas da carteira estão geralmente disponíveis e prontas para atender pedidos, o que pode ser uma vantagem competitiva
#    - A disponibilidade de produtos na carteira de restaurantes varia entre 82% e 91% ao longo das semanas analisadas. Isso indica que há certa variabilidade.
#    - A média de "% Desconto da carteira" é 5% e da "% Vertical Restaurantes" é de 11%. Podemos aumentar taxa de desconto para a média da vertical de restaurante para atrair novos clientes.
#
# 3. **O que você faria como proposta para crescer o funil de conversões como um todo da carteira?**
#    - Realizar uma análise detalhada das causas raiz para a variabilidade na disponibilidade de produtos da carteira. Isso pode ajudar a melhorar a eficiência operacional e a satisfação do cliente (menores cancelamentos e por consequência maior conversão).
#    - Em "Visualizações de Produto (VPD)", podemos melhorar as imagens de produtos e descrição dos produtos, e também pode ser feito testes A/B com diferentes imagens mais atrativas para atrair clientes a adicionar ao carrinho.
#    - Analisar os pontos positivos do Usuário 1, como nas etapas de "Proceder ao Checkout (PTC)", "Pedidos Selecionados (OP)" e "pedidos confirmados (OPC)", e aplicar no Usuário 2 para aumentar a conversão e satisfação do cliente.
#    - Implementar campanhas de incentivos ou descontos específicos para aumentar as adições ao carrinho e os checkouts (criar campanhas durante os jogos do brasil cada gol é mais 1% de desconto, ou campanhas de festas e feriados da região da carteira. (Usando Segmentação de Clientes com ‘Análise RFM’)
#    - % Desconto da carteira é 5% e da % Vertical Restaurantes é de 11%. Podemos aumentar o desconto para atrair novos clientes.
#
# 4. **Qual seria o seu approach com o parceiro e qual proposta você faria para aumentar as conversões?**
#    - Baseadoce nas métricas, fornecer feedback detalhado e estratégias personalizadas para cada parceiro com foco nas áreas identificadas como pontos fracos.
#
# ## **Resultados**
#
# ### Sessões
# A análise revelou que a visão geral dos restaurantes apresenta valores mais altos para quase todas as métricas de sessões em comparação com a carteira de restaurantes.
#
# ### Conversões
# As taxas de conversão da visão geral são superiores em várias etapas do funil, especialmente nas etapas de conversão de pedidos, indicando áreas de melhoria para a carteira.
#
# ## **Próximos Passos**
#
# 1. **Análise Detalhada dos Pontos de Ruptura**: Realizar uma análise mais profunda para identificar as causas dos pontos de ruptura no funil de conversão.
# 2. **Implementação de Ações Específicas**: Propor e implementar ações específicas para melhorar as métricas de sessões e conversões da carteira.
# 3. **Monitoramento e Ajuste Contínuo**: Monitorar continuamente as métricas e ajustar as estratégias conforme necessário para garantir a melhoria contínua.
#
# ## **Conclusão**
#
# **RappiBoost** é um projeto crucial para elevar a performance dos restaurantes parceiros na Rappi, utilizando insights baseados em dados para tomar decisões informadas e estratégias eficazes. Com a implementação das ações propostas, espera-se um aumento significativo nas taxas de conversão e na satisfação dos usuários.
#
# ## **Links de Apoio**
#
# 1. [Dados de Apoio](https://docs.google.com/spreadsheets/d/1gZoP44Q62UbFiHnHPL6byc5TWf44KzryL2HMga908P0/edit?usp=sharing): Google sheets com dados do business case.
# 2. [Slides Apresentação](https://docs.google.com/presentation/d/1Z--ywI3AZ_yKAVrI41jiqOylvIslSqVvHxiEzjpYIkM/edit?usp=sharing): Slides contendo os insights extraídos da base de dados de apoio.

# %% [markdown]
# # Importando Base dos Dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_csv_file(file_path, sep, encoding='utf-8'):
    """
    Esta função carrega um arquivo CSV, realiza o tratamento da coluna 'SEMANA' e retorna um DataFrame.

    Argumentos:
        file_path (str): Caminho para o arquivo CSV.
        sep (str): Separador de campo no CSV.

    Retorno:
        pandas.DataFrame: DataFrame com as colunas do CSV, incluindo a coluna 'SEMANA' tratada.

    Exceções:
        FileNotFoundError: Se o arquivo CSV não for encontrado.
        Exception: Se ocorrerem outros erros durante a execução da função.
    """
    try:
        df = pd.read_csv(file_path, sep=sep, encoding=encoding)

        if "SEMANA" in df.columns:
            try:
                df["SEMANA"] = pd.to_datetime(df["SEMANA"])
            except Exception as e:
                print(f"Erro ao converter a coluna 'SEMANA' para datetime: {e}")

        return df
    except FileNotFoundError as e:
        print(f"Arquivo CSV não encontrado: {file_path}")
        raise
    except Exception as e:
        print(f"Erro inesperado ao carregar o CSV: {e}")
        raise

# %%
def rename_columns(df):
    """
      Renomeia as colunas de um DataFrame Pandas de acordo com um dicionário predefinido de novos nomes.

      Este função verifica primeiro se as colunas especificadas existem no DataFrame. Se existirem,
      as colunas são renomeadas de acordo com as regras definidas no dicionário 'colunas_novas'.
      Caso contrário, uma mensagem informando que nenhuma coluna foi encontrada para renomear é exibida.

      Parâmetros:
      df (pandas.DataFrame): O DataFrame cujas colunas devem ser renomeadas.

      Retorna:
      pandas.DataFrame: O DataFrame com as colunas renomeadas, se aplicável.

    """

    # Dicionário das novas colunas com seus nomes
    colunas_novas = {
        "SS": "sessoes_na_loja",
        "SST": "sessoes_na_vertical",
        "VPD": "sessoes_de_visualizacao_de_produto",
        "ATC": "sessoes_de_adicao_de_produto_ao_carrinho",
        "PTC": "sessoes_de_proceder_ao_checkout",
        "OP": "sessoes_de_pedidos_solicitados",
        "OPC": "sessoes_de_pedidos_confirmados"
    }

    # Lista de colunas que realmente existem no DataFrame
    colunas_existentes = [coluna for coluna in colunas_novas.keys() if coluna in df.columns]

    if colunas_existentes:
        # Renomeando as colunas existentes
        df.rename(columns={coluna: colunas_novas[coluna] for coluna in colunas_existentes}, inplace=True)
        #print("Colunas renomeadas com sucesso: ", colunas_existentes)

    return df

# %%
# Visão Geral Restaurantes: Sessoes
df_visao_geral_restaurantes_sessoes = load_csv_file('visao_geral_restaurantes_sessoes.csv', sep=",")
#df_visao_geral_restaurantes_sessoes = rename_columns(df_visao_geral_restaurantes_sessoes)
df_visao_geral_restaurantes_sessoes.head()
# Out:
#       SEMANA     SST      SS     VPD     ATC     PTC      OP    OPC
# 0 2024-04-01  333353  282903  167252  161170  143719  112300  89739
# 1 2024-04-08  335318  282024  163959  155293  136843  108504  88229
# 2 2024-04-15  312760  263641  153321  144305  127063  102350  83539
# 3 2024-04-22  322983  271334  160539  152300  133875  106800  86282
# 4 2024-04-29  340531  278384  168373  159929  140734  111184  89760

# %%
# Visão Geral Restaurantes: Conversões
df_visao_geral_restaurantes_conversoes = load_csv_file('visao_geral_restaurantes_conversoes.csv', sep=",")
df_visao_geral_restaurantes_conversoes.head()
# Out:
#       SEMANA SST-OPC SST-SS SS-VPD SS-ATC VPD-ATC ATC-PTC PTC-OP OP-OPC  \
# 0 2024-04-01     27%    85%    59%    57%     96%     89%    78%    80%
# 1 2024-04-08     26%    84%    58%    55%     95%     88%    79%    81%
# 2 2024-04-15     27%    84%    58%    55%     94%     88%    81%    82%
# 3 2024-04-22     27%    84%    59%    56%     95%     88%    80%    81%
# 4 2024-04-29     26%    82%    60%    57%     95%     88%    79%    81%
#
#   STORE_AVAILABILITY PRODUCT_AVAILABILITY DESCONTO_PERCENTUAL
# 0                90%                  85%                 12%
# 1                89%                  91%                 12%
# 2                89%                  88%                 10%
# 3                87%                  88%                 10%
# 4                86%                  86%                 10%

# %%
# Sessoes Conversao Usuarios 1
df_sessoes_conversao_usuarios1 = load_csv_file('sessoes_conversao_usuarios1.csv', sep=",")
df_sessoes_conversao_usuarios1.head()
# Out:
#       SEMANA     SST      SS     VPD     ATC     PTC     OP    OPC SST-OPC  \
# 0 2024-04-01  225676  196397  123394  118159  106138  87078  76233     34%
# 1 2024-04-08  229015  196097  121376  113920  100878  84052  74861     33%
# 2 2024-04-15  209503  180579  112129  104508   92586  78681  70492     34%
# 3 2024-04-22  216203  186606  117104  110137   97471  81589  72746     34%
# 4 2024-04-29  229808  191096  123061  114916  101454  84009  75196     33%
#
#   SST-SS SS-VPD SS-ATC VPD-ATC ATC-PTC PTC-OP OP-OPC
# 0    87%    63%    60%     96%     90%    82%    88%
# 1    86%    62%    58%     94%     89%    83%    89%
# 2    86%    62%    58%     93%     89%    85%    90%
# 3    86%    63%    59%     94%     88%    84%    89%
# 4    83%    64%    60%     93%     88%    83%    90%

# %%
# Sessoes Conversao Usuarios 2
df_sessoes_conversao_usuarios2 = load_csv_file('sessoes_conversao_usuarios2.csv', sep=",")
df_sessoes_conversao_usuarios2.head()
# Out:
#       SEMANA    SST     SS    VPD    ATC    PTC     OP   OPC SST-OPC SST-SS  \
# 0 2024-04-01  64095  49396  25241  25901  22632  14998  7806     12%    77%
# 1 2024-04-08  62317  48742  23671  24335  21124  14139  7399     12%    78%
# 2 2024-04-15  60115  46705  23046  23386  20207  13564  7255     12%    78%
# 3 2024-04-22  61922  47391  24091  24138  20737  14071  7460     12%    77%
# 4 2024-04-29  64072  48083  24637  25041  21683  14592  7604     12%    75%
#
#   SS-VPD SS-ATC VPD-ATC ATC-PTC PTC-OP OP-OPC
# 0    51%    52%    103%     87%    66%    52%
# 1    49%    50%    103%     87%    67%    52%
# 2    49%    50%    101%     86%    67%    53%
# 3    51%    51%    100%     86%    68%    53%
# 4    51%    52%    102%     87%    67%    52%

# %%
# Visao Carteira: Conversões
df_visao_carteira_conversoes = load_csv_file('visao_carteira_conversoes.csv', sep=",")
df_visao_carteira_conversoes.head()
# Out:
#       SEMANA SST-OPC SST-SS SS-VPD SS-ATC VPD-ATC ATC-PTC PTC-OP OP-OPC  \
# 0 2024-04-01     17%   100%    54%    49%     89%     85%    60%    70%
# 1 2024-04-08     17%   100%    52%    45%     88%     84%    62%    71%
# 2 2024-04-15     15%   100%    48%    40%     83%     82%    63%    71%
# 3 2024-04-22     18%   100%    53%    47%     90%     84%    63%    71%
# 4 2024-04-29     18%   100%    55%    49%     90%     83%    59%    72%
#
#   STORE_AVAILABILITY PRODUCT_AVAILABILITY DESCONTO_PERCENTUAL
# 0                98%                  87%                  5%
# 1                98%                  87%                  5%
# 2                98%                  82%                  5%
# 3                98%                  87%                  5%
# 4                98%                  87%                  5%

# %%
# Visao Carteira: Sessões
df_visao_carteira_sessoes = load_csv_file('visao_carteira_sessoes.csv', sep=",")
df_visao_carteira_sessoes.head()
# Out:
#       SEMANA    SST     SS    VPD    ATC    PTC     OP    OPC
# 0 2024-04-01  71571  71571  38894  34718  29668  17848  12426
# 1 2024-04-08  71568  71568  37052  32444  27165  16921  12035
# 2 2024-04-15  62981  62981  30141  25020  20536  12851   9143
# 3 2024-04-22  64804  64804  34034  30727  25853  16374  11674
# 4 2024-04-29  64577  64577  35497  31934  26516  15749  11348

# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# ### Gráfico Geral: Sessões Semanais com Linha de Média na Vertical Restaurantes
#
# - **Título:** Sessões Semanais em Restaurantes
# - **Descrição:** Este gráfico mostra o total de sessões (SST) em restaurantes a cada semana. As barras representam a quantidade de sessões registradas semanalmente, com uma linha vermelha pontilhada indicando a média semanal. Os valores numéricos em cima das barras facilitam a visualização dos dados específicos.

# %%
df_data_weekly = df_visao_geral_restaurantes_sessoes

# Convertendo colunas
df_data_weekly['SST'] = df_data_weekly['SST'].astype('int64')
df_data_weekly['SS'] = df_data_weekly['SS'].astype('int64')
df_data_weekly['OP'] = df_data_weekly['OP'].astype('int64')
df_data_weekly['OPC'] = df_data_weekly['OPC'].astype('int64')

numeric_cols = df_data_weekly.select_dtypes(include='number').columns
weekly_data = df_data_weekly.groupby('SEMANA')[numeric_cols].sum().reset_index()

sns.set()

# Cálculo da média semanal
weekly_mean = weekly_data['SST'].mean()

def format_number(value):
    return f'{value:,.0f}'.replace(',', 'X').replace('.', ',').replace('X', '.')

plt.figure(figsize=(14, 7))
sns.barplot(x='SEMANA', y='SST', data=weekly_data)
plt.axhline(weekly_mean, color='red', linestyle='--', label=f'Média: {format_number(weekly_mean)}')
plt.title('Sessões Semanais na Vertical Restaurantes', fontsize=16)
plt.xlabel('Semana', fontsize=14)
plt.ylabel('Total de Sessões na Vertical (SST)', fontsize=14)
plt.xticks(rotation=45)
for index, row in weekly_data.iterrows():
    plt.text(index, row.SST, format_number(row.SST), color='black', ha="center", fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Média e Mediana da Visão Geral Restaurantes: Sessoes
# Calcular a média e a mediana para cada coluna numérica
mean_values = df_visao_geral_restaurantes_sessoes.mean(numeric_only=True).round(0)
median_values = df_visao_geral_restaurantes_sessoes.median(numeric_only=True).round(0)

stats_df_visao_geral_restaurantes_sessoes = pd.DataFrame({
    'Estatística': ['Média', 'Mediana'],
    'SST': [mean_values['SST'].astype('int64'), median_values['SST'].astype('int64')],
    'SS': [mean_values['SS'].astype('int64'), median_values['SS'].astype('int64')],
    'VPD': [mean_values['VPD'].astype('int64'), median_values['VPD'].astype('int64')],
    'ATC': [mean_values['ATC'].astype('int64'), median_values['ATC'].astype('int64')],
    'PTC': [mean_values['PTC'].astype('int64'), median_values['PTC'].astype('int64')],
    'OP': [mean_values['OP'].astype('int64'), median_values['OP'].astype('int64')],
    'OPC': [mean_values['OPC'].astype('int64'), median_values['OPC'].astype('int64')]
})

stats_df_visao_geral_restaurantes_sessoes.head()
# Out:
#   Estatística     SST      SS     VPD     ATC     PTC      OP    OPC
# 0       Média  314794  261815  153068  144080  126548  100633  82194
# 1     Mediana  314287  266203  153321  145190  127063  102115  83539

# %% [markdown]
# ### Gráfico Geral: Sessões Mensais com Linha de Média na Vertical Restaurantes
#
# - **Título:** Sessões Mensais em Restaurantes
# - **Descrição:** Este gráfico mostra o total de sessões (SST) em restaurantes a cada mês. As barras representam a quantidade de sessões registradas mensalmente, com uma linha vermelha pontilhada indicando a média mensal. Os valores numéricos em cima das barras facilitam a visualização dos dados específicos.

# %%
df_data_month_sst = df_visao_geral_restaurantes_sessoes

df_data_month_sst['SST'] = df_data_month_sst['SST'].astype('int64')
df_data_month_sst['SS'] = df_data_month_sst['SS'].astype('int64')
df_data_month_sst['OP'] = df_data_month_sst['OP'].astype('int64')
df_data_month_sst['OPC'] = df_data_month_sst['OPC'].astype('int64')

df_visao_geral_restaurantes_sessoes['MES'] = df_visao_geral_restaurantes_sessoes['SEMANA'].dt.to_period('M')

numeric_cols = df_visao_geral_restaurantes_sessoes.select_dtypes(include='number').columns

monthly_data = df_visao_geral_restaurantes_sessoes.groupby('MES')[numeric_cols].sum().reset_index()

meses_para_projecao = monthly_data[monthly_data['MES'].astype(str).isin(['2024-04', '2024-05'])]

if not meses_para_projecao.empty:
    projection_june = meses_para_projecao['SST'].mean()

    projection_data = pd.DataFrame({'MES': ['2024-06 (Projeção)'], 'SST': [int(projection_june)]})

    monthly_data = pd.concat([monthly_data, projection_data], ignore_index=True)

    sns.set()

    monthly_mean = monthly_data[monthly_data['MES'] != '2024-06 (Projeção)']['SST'].mean()

    def format_number(value):
        return f'{value:,.0f}'.replace(',', 'X').replace('.', ',').replace('X', '.')

    monthly_data['color'] = ['Projeção' if x == '2024-06 (Projeção)' else 'Real' for x in monthly_data['MES']]

    # Calcular a diferença percentual entre os meses
    monthly_data['percent_change'] = monthly_data['SST'].pct_change() * 100
    monthly_data['percent_change'] = monthly_data['percent_change'].round(2).astype(str) + '%'

    # Remover a diferença percentual da projeção
    monthly_data.loc[monthly_data['MES'] == '2024-06 (Projeção)', 'percent_change'] = ''

    plt.figure(figsize=(14, 7))
    sns.barplot(x='MES', y='SST', data=monthly_data, hue='color', dodge=False, palette={'Projeção': 'grey', 'Real': '#4c72b0'})
    plt.axhline(monthly_mean, color='red', linestyle='--', label=f'Média: {format_number(monthly_mean)}')
    plt.title('Sessões Mensais em Restaurantes', fontsize=16)
    plt.xlabel('Mês', fontsize=14)
    plt.ylabel('Total de Sessões na Vertical (SST)', fontsize=14)
    plt.xticks(rotation=45)
    for index, row in monthly_data.iterrows():
        plt.text(index, row.SST, format_number(row.SST), color='black', ha="center", fontsize=12)
        if row['percent_change'] != '':
            plt.text(index, row.SST * 0.92, row['percent_change'], color='white', ha="center", fontsize=10)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print("Os meses 2024-04 e 2024-05 não estão presentes nos dados para calcular a projeção.")

# %% [markdown]
# ### **Gráfico Geral: Conversão Semanal com Linha de Média na Vertical Restaurantes**
#
# - **Título:** Conversão Semanal em Restaurantes
# - **Descrição:** Este gráfico mostra a média de conversões semanais (SST-OPC) na vertical de restaurantes. As barras representam a média semanal de conversões registradas, com uma linha vermelha pontilhada indicando a média semanal. A projeção para a semana de 17 de junho é incluída com uma cor diferenciada.

# %%
df_data_weekly_sst = df_visao_geral_restaurantes_conversoes[['SEMANA', 'SST-OPC']].copy()
df_data_weekly_sst['SST-OPC'] = df_data_weekly_sst['SST-OPC'].str.rstrip('%').astype('int64')
df_data_weekly_sst['SEMANA'] = pd.to_datetime(df_data_weekly_sst['SEMANA'], format='%Y-%m-%d')

weekly_data = df_data_weekly_sst.groupby('SEMANA')['SST-OPC'].mean().reset_index()

# Definir a semana de projeção e as quatro semanas anteriores
semana_projecao = '2024-06-17'
semanas_anteriores = pd.date_range(end=semana_projecao, periods=5, freq='W-MON')[:-1]

semanas_para_projecao = weekly_data[weekly_data['SEMANA'].isin(semanas_anteriores)]

if not semanas_para_projecao.empty:
    # Calcular a média das quatro semanas anteriores
    projection_value = semanas_para_projecao['SST-OPC'].mean()

    # Adicionar a projeção da semana
    projection_data = pd.DataFrame({'SEMANA': [semana_projecao + ' (Projeção)'], 'SST-OPC': [int(projection_value)]})
    weekly_data = pd.concat([weekly_data, projection_data], ignore_index=True)

    # Configurar o estilo do Seaborn
    sns.set()

    # Calcular a média semanal excluindo a projeção
    weekly_mean = weekly_data[weekly_data['SEMANA'] != semana_projecao + ' (Projeção)']['SST-OPC'].mean()

    def format_number(value):
        return f'{value:,.0f}%'.replace(',', 'X').replace('.', ',').replace('X', '.')

    # Adicionar a coluna de cores para diferenciar os dados reais da projeção
    weekly_data['color'] = ['Projeção' if x == semana_projecao + ' (Projeção)' else 'Real' for x in weekly_data['SEMANA']]

    # Plotar o gráfico
    plt.figure(figsize=(14, 7))
    sns.barplot(x='SEMANA', y='SST-OPC', data=weekly_data, hue='color', dodge=False, palette={'Projeção': 'grey', 'Real': '#4c72b0'})
    plt.axhline(weekly_mean, color='red', linestyle='--', label=f'Média: {format_number(weekly_mean)}')
    plt.title('Conversões Semanais na Vertical Restaurantes com Projeção para 17 de Junho', fontsize=16)
    plt.xlabel('Semana', fontsize=14)
    plt.ylabel('Média de Conversões na Vertical (SST-OPC)', fontsize=14)
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(plt.FixedFormatter(weekly_data['SEMANA'].apply(lambda x: x.strftime('%Y-%m-%d') if isinstance(x, pd.Timestamp) else x)))
    for index, row in weekly_data.iterrows():
        plt.text(index, row['SST-OPC'], format_number(row['SST-OPC']), color='black', ha="center", fontsize=12)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print(f"As semanas anteriores a {semana_projecao} não estão presentes nos dados para calcular a projeção.")
# Out:
# <ipython-input-43-e04dd8b729d8>:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().xaxis.set_major_formatter(plt.FixedFormatter(weekly_data['SEMANA'].apply(lambda x: x.strftime('%Y-%m-%d') if isinstance(x, pd.Timestamp) else x)))

# %% [markdown]
# ### Gráfico Geral: Conversão Mensal com Linha de Média na Vertical Restaurantes
#
# - **Título:** Conversão Mensais em Restaurantes
# - **Descrição:** Este gráfico mostra o total de Conversão (SST-OPC) na vertical restaurantes a cada mês. As barras representam a porcentagem de conversão registradas mensalmente, com uma linha vermelha pontilhada indicando a média mensal. Os valores numéricos em cima das barras facilitam a visualização dos dados específicos.

# %%
df_data_month_sst = df_visao_geral_restaurantes_conversoes[['SEMANA', 'SST-OPC']].copy()

df_data_month_sst['SST-OPC'] = df_data_month_sst['SST-OPC'].str.rstrip('%').astype('int64')
df_data_month_sst['SEMANA'] = pd.to_datetime(df_data_month_sst['SEMANA'], format='%Y-%m-%d')
df_data_month_sst['MES'] = df_data_month_sst['SEMANA'].dt.to_period('M')

monthly_data = df_data_month_sst.groupby('MES')['SST-OPC'].mean().reset_index()

meses_para_projecao = monthly_data[monthly_data['MES'].astype(str).isin(['2024-04', '2024-05'])]

if not meses_para_projecao.empty:
    # Calcular a média das conversões de Abril e Maio
    projection_june = meses_para_projecao['SST-OPC'].mean()

    # Adicionar a projeção de Junho aos dados mensais
    projection_data = pd.DataFrame({'MES': ['2024-06 (Projeção)'], 'SST-OPC': [int(projection_june)]})
    monthly_data = pd.concat([monthly_data, projection_data], ignore_index=True)

    # Configurar o estilo do Seaborn
    sns.set()

    # Calcular a média mensal excluindo a projeção
    monthly_mean = monthly_data[monthly_data['MES'] != '2024-06 (Projeção)']['SST-OPC'].mean()

    def format_number(value):
        return f'{value:,.0f}%'.replace(',', 'X').replace('.', ',').replace('X', '.')

    # Adicionar a coluna de cores para diferenciar os dados reais da projeção
    monthly_data['color'] = ['Projeção' if x == '2024-06 (Projeção)' else 'Real' for x in monthly_data['MES']]

    # Plotar o gráfico
    plt.figure(figsize=(14, 7))
    sns.barplot(x='MES', y='SST-OPC', data=monthly_data, hue='color', dodge=False, palette={'Projeção': 'grey', 'Real': '#4c72b0'})
    plt.axhline(monthly_mean, color='red', linestyle='--', label=f'Média: {format_number(monthly_mean)}')
    plt.title('Conversões Mensais na Vertical Restaurantes com Projeção para Junho', fontsize=16)
    plt.xlabel('Mês', fontsize=14)
    plt.ylabel('Média de Conversões na Vertical (SST-OPC)', fontsize=14)
    plt.xticks(rotation=45)
    for index, row in monthly_data.iterrows():
        plt.text(index, row['SST-OPC'], format_number(row['SST-OPC']), color='black', ha="center", fontsize=12)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print("Os meses 2024-04 e 2024-05 não estão presentes nos dados para calcular a projeção.")

# %% [markdown]
# ### Gráfico Geral: Funil de Sessões Mensal na Vertical Restaurantes
#
# - **Título:** Análise de Sessões Mensal na Sessões Restaurantes
# - **Descrição:** Este gráfico de funil ilustra a performance das sessões através das diferentes etapas do funil de vendas para a vertical de restaurantes ao longo dos meses. As etapas analisadas incluem Sessões na Vertical (SST), Sessões na Loja (SS), Sessões de Visualização de Produto (VPD), Sessões de Adição de Produto ao Carrinho (ATC), Sessões de Proceder ao Checkout (PTC), Sessões de Pedidos Solicitados (OP), e Sessões de Pedidos Confirmados (OPC). Cada ponto no gráfico representa o total acumulado para cada etapa, e os valores exibidos indicam tanto o total absoluto quanto a variação percentual em relação à etapa anterior, proporcionando uma visão clara das taxas de sessões e perdas em cada estágio do funil.

# %%
df_data_month_sst = df_visao_geral_restaurantes_sessoes

# Convertendo colunas
df_data_month_sst['SST'] = df_data_month_sst['SST'].astype('int64')
df_data_month_sst['SS'] = df_data_month_sst['SS'].astype('int64')
df_data_month_sst['VPD'] = df_data_month_sst['VPD'].astype('int64')
df_data_month_sst['ATC'] = df_data_month_sst['ATC'].astype('int64')
df_data_month_sst['PTC'] = df_data_month_sst['PTC'].astype('int64')
df_data_month_sst['OP'] = df_data_month_sst['OP'].astype('int64')
df_data_month_sst['OPC'] = df_data_month_sst['OPC'].astype('int64')

# Criar colunas adicionais para 'Mês'
df_data_month_sst['MES'] = df_data_month_sst['SEMANA'].dt.to_period('M')

# Agrupar os dados por mês e somar apenas as colunas numéricas relevantes
monthly_data = df_data_month_sst.groupby('MES')[['SST', 'SS', 'VPD', 'ATC', 'PTC', 'OP', 'OPC']].sum().reset_index()

# Configurações do tema
sns.set()

# Função para formatar os números com pontos como separadores de milhar e vírgulas como separadores decimais
def format_number(value):
    return f'{value:,.0f}'.replace(',', 'X').replace('.', ',').replace('X', '.')

# Gráfico de Funil Mensal
fig, ax = plt.subplots(figsize=(16, 9))

for i, row in monthly_data.iterrows():
    funnel_values = [row['SST'], row['SS'], row['VPD'], row['ATC'], row['PTC'], row['OP'], row['OPC']]
    ax.plot([0, 1, 2, 3, 4, 5, 6], funnel_values, marker='o', label=str(row['MES']))
    for j, value in enumerate(funnel_values):
        if j > 0:
            percent_change = (funnel_values[j] - funnel_values[j-1]) / funnel_values[j-1] * 100
            ax.text(j, value, f"{format_number(value)} ({percent_change:.2f}%)", color='black', ha="center", fontsize=12)
        else:
            ax.text(j, value, format_number(value), color='black', ha="center", fontsize=12)

ax.set_xticks([0, 1, 2, 3, 4, 5, 6])
ax.set_xticklabels([
    'Sessões na Vertical\n(SST)',
    'Sessões na Loja\n(SS)',
    'Visualizações de Produto\n(VPD)',
    'Adições ao Carrinho\n(ATC)',
    'Proceder ao Checkout\n(PTC)',
    'Pedidos Solicitados\n(OP)',
    'Pedidos Confirmados\n(OPC)'
], rotation=0)
ax.set_title('Análise de Sessões Mensal na Vertical Restaurantes', fontsize=16)
ax.set_xlabel('Etapas', fontsize=14)
ax.set_ylabel('Total', fontsize=14)
ax.legend(title='Mês')
plt.tight_layout()
plt.show()

# %%
# Média e Mediana da Visão Geral Restaurantes: Conversões

for column in df_visao_geral_restaurantes_conversoes.columns[1:]:
    df_visao_geral_restaurantes_conversoes[column] = df_visao_geral_restaurantes_conversoes[column].str.rstrip('%').astype(float) / 100.0

mean_values_new_2 = (df_visao_geral_restaurantes_conversoes.mean(numeric_only=True) * 100).round(0)
median_values_new_2 = (df_visao_geral_restaurantes_conversoes.median(numeric_only=True) * 100).round(0)

stats_df_visao_geral_restaurantes_conversoes = pd.DataFrame({
    'Estatística': ['Média', 'Mediana'],
    'SST-OPC': [f"{mean_values_new_2['SST-OPC']}%", f"{median_values_new_2['SST-OPC']}%"],
    'SST-SS': [f"{mean_values_new_2['SST-SS']}%", f"{median_values_new_2['SST-SS']}%"],
    'SS-VPD': [f"{mean_values_new_2['SS-VPD']}%", f"{median_values_new_2['SS-VPD']}%"],
    'SS-ATC': [f"{mean_values_new_2['SS-ATC']}%", f"{median_values_new_2['SS-ATC']}%"],
    'VPD-ATC': [f"{mean_values_new_2['VPD-ATC']}%", f"{median_values_new_2['VPD-ATC']}%"],
    'ATC-PTC': [f"{mean_values_new_2['ATC-PTC']}%", f"{median_values_new_2['ATC-PTC']}%"],
    'PTC-OP': [f"{mean_values_new_2['PTC-OP']}%", f"{median_values_new_2['PTC-OP']}%"],
    'OP-OPC': [f"{mean_values_new_2['OP-OPC']}%", f"{median_values_new_2['OP-OPC']}%"],
    'STORE_AVAILABILITY': [f"{mean_values_new_2['STORE_AVAILABILITY']}%", f"{median_values_new_2['STORE_AVAILABILITY']}%"],
    'PRODUCT_AVAILABILITY': [f"{mean_values_new_2['PRODUCT_AVAILABILITY']}%", f"{median_values_new_2['PRODUCT_AVAILABILITY']}%"],
    'DESCONTO_PERCENTUAL': [f"{mean_values_new_2['DESCONTO_PERCENTUAL']}%", f"{median_values_new_2['DESCONTO_PERCENTUAL']}%"]
})

stats_df_visao_geral_restaurantes_conversoes.head()
# Out:
#   Estatística SST-OPC SST-SS SS-VPD SS-ATC VPD-ATC ATC-PTC PTC-OP OP-OPC  \
# 0       Média   26.0%  83.0%  58.0%  55.0%   94.0%   88.0%  80.0%  82.0%
# 1     Mediana   27.0%  83.0%  58.0%  55.0%   94.0%   88.0%  79.0%  82.0%
#
#   STORE_AVAILABILITY PRODUCT_AVAILABILITY DESCONTO_PERCENTUAL
# 0              89.0%                87.0%               11.0%
# 1              90.0%                88.0%               11.0%

# %% [markdown]
# ### Gráfico Carteira: Funil de Sessões Mensal da Carteira
#
# - **Título:** Análise de Sessões Mensal na Carteira
# - **Descrição:** Este gráfico de funil ilustra a performance das sessões através das diferentes etapas do funil de vendas para a carteira ao longo dos meses. As etapas analisadas incluem Sessões na Vertical (SST), Sessões na Loja (SS), Sessões de Visualização de Produto (VPD), Sessões de Adição de Produto ao Carrinho (ATC), Sessões de Proceder ao Checkout (PTC), Sessões de Pedidos Solicitados (OP), e Sessões de Pedidos Confirmados (OPC). Cada ponto no gráfico representa o total acumulado para cada etapa, e os valores exibidos indicam tanto o total absoluto quanto a variação percentual em relação à etapa anterior, proporcionando uma visão clara das taxas de sessões e perdas em cada estágio do funil.

# %%
df_data_month_sst = df_visao_carteira_sessoes

# Criar colunas adicionais para 'Mês'
df_data_month_sst['MES'] = df_data_month_sst['SEMANA'].dt.to_period('M')

# Agrupar os dados por mês e somar apenas as colunas numéricas relevantes
monthly_data = df_data_month_sst.groupby('MES')[['SST', 'SS', 'VPD', 'ATC', 'PTC', 'OP', 'OPC']].sum().reset_index()

# Configurações do tema
sns.set()

# Função para formatar os números com pontos como separadores de milhar e vírgulas como separadores decimais
def format_number(value):
    return f'{value:,.0f}'.replace(',', 'X').replace('.', ',').replace('X', '.')

# Gráfico de Funil Mensal
fig, ax = plt.subplots(figsize=(16, 9))

for i, row in monthly_data.iterrows():
    funnel_values = [row['SST'], row['SS'], row['VPD'], row['ATC'], row['PTC'], row['OP'], row['OPC']]
    ax.plot([0, 1, 2, 3, 4, 5, 6], funnel_values, marker='o', label=str(row['MES']))
    for j, value in enumerate(funnel_values):
        if j > 0:
            percent_change = (funnel_values[j] - funnel_values[j-1]) / funnel_values[j-1] * 100
            ax.text(j, value, f"{format_number(value)} ({percent_change:.2f}%)", color='black', ha="center", fontsize=12)
        else:
            ax.text(j, value, format_number(value), color='black', ha="center", fontsize=12)

ax.set_xticks([0, 1, 2, 3, 4, 5, 6])
ax.set_xticklabels([
    'Sessões na Vertical\n(SST)',
    'Sessões na Loja\n(SS)',
    'Visualizações de Produto\n(VPD)',
    'Adições ao Carrinho\n(ATC)',
    'Proceder ao Checkout\n(PTC)',
    'Pedidos Solicitados\n(OP)',
    'Pedidos Confirmados\n(OPC)'
], rotation=0)
ax.set_title('Análise de Sessões Mensais da Carteira', fontsize=16)
ax.set_xlabel('Etapas', fontsize=14)
ax.set_ylabel('Total', fontsize=14)
ax.legend(title='Mês')
plt.tight_layout()
plt.show()

# %%
# Média e Mediana da Visao Carteira: Sessões
# Calcular a média e a mediana para cada coluna numérica
mean_values = df_visao_carteira_sessoes.mean(numeric_only=True).round(0)
median_values = df_visao_carteira_sessoes.median(numeric_only=True).round(0)

stats_visao_carteira_sessoes = pd.DataFrame({
    'Estatística': ['Média', 'Mediana'],
    'SST': [mean_values['SST'].astype('int64'), median_values['SST'].astype('int64')],
    'SS': [mean_values['SS'].astype('int64'), median_values['SS'].astype('int64')],
    'VPD': [mean_values['VPD'].astype('int64'), median_values['VPD'].astype('int64')],
    'ATC': [mean_values['ATC'].astype('int64'), median_values['ATC'].astype('int64')],
    'PTC': [mean_values['PTC'].astype('int64'), median_values['PTC'].astype('int64')],
    'OP': [mean_values['OP'].astype('int64'), median_values['OP'].astype('int64')],
    'OPC': [mean_values['OPC'].astype('int64'), median_values['OPC'].astype('int64')]
})

stats_visao_carteira_sessoes.head()
# Out:
#   Estatística    SST     SS    VPD    ATC    PTC     OP    OPC
# 0       Média  63707  63707  33155  28826  23982  14906  10641
# 1     Mediana  64402  64402  34034  29267  23949  14893  10404

# %%
# Média e Mediana da Visao Carteira: Conversões
for column in df_visao_carteira_conversoes.columns[1:]:
    df_visao_carteira_conversoes[column] = df_visao_carteira_conversoes[column].str.rstrip('%').astype(float) / 100.0

mean_values_new = (df_visao_carteira_conversoes.mean(numeric_only=True) * 100).round(1)
median_values_new = (df_visao_carteira_conversoes.median(numeric_only=True) * 100).round(1)

stats_df_percent = pd.DataFrame({
    'Estatística': ['Média', 'Mediana'],
    'SST-OPC': [f"{mean_values_new['SST-OPC']}%", f"{median_values_new['SST-OPC']}%"],
    'SST-SS': [f"{mean_values_new['SST-SS']}%", f"{median_values_new['SST-SS']}%"],
    'SS-VPD': [f"{mean_values_new['SS-VPD']}%", f"{median_values_new['SS-VPD']}%"],
    'SS-ATC': [f"{mean_values_new['SS-ATC']}%", f"{median_values_new['SS-ATC']}%"],
    'VPD-ATC': [f"{mean_values_new['VPD-ATC']}%", f"{median_values_new['VPD-ATC']}%"],
    'ATC-PTC': [f"{mean_values_new['ATC-PTC']}%", f"{median_values_new['ATC-PTC']}%"],
    'PTC-OP': [f"{mean_values_new['PTC-OP']}%", f"{median_values_new['PTC-OP']}%"],
    'OP-OPC': [f"{mean_values_new['OP-OPC']}%", f"{median_values_new['OP-OPC']}%"],
    'STORE_AVAILABILITY': [f"{mean_values_new['STORE_AVAILABILITY']}%", f"{median_values_new['STORE_AVAILABILITY']}%"],
    'PRODUCT_AVAILABILITY': [f"{mean_values_new['PRODUCT_AVAILABILITY']}%", f"{median_values_new['PRODUCT_AVAILABILITY']}%"],
    'DESCONTO_PERCENTUAL': [f"{mean_values_new['DESCONTO_PERCENTUAL']}%", f"{median_values_new['DESCONTO_PERCENTUAL']}%"]
})

stats_df_percent.head()
# Out:
#   Estatística SST-OPC  SST-SS SS-VPD SS-ATC VPD-ATC ATC-PTC PTC-OP OP-OPC  \
# 0       Média   16.7%  100.0%  52.1%  45.3%   86.8%   83.2%  62.0%  71.5%
# 1     Mediana   17.0%  100.0%  53.0%  46.0%   87.0%   83.0%  62.0%  71.0%
#
#   STORE_AVAILABILITY PRODUCT_AVAILABILITY DESCONTO_PERCENTUAL
# 0              98.0%                86.3%                5.0%
# 1              98.0%                87.0%                5.0%

# %% [markdown]
# ### **Gráfico Carteira: Conversões Semanais na Carteira com Projeção para 17 de Junho**
#
# - **Título:** Conversões Semanais na Carteira com Projeção para 17 de Junho
# - **Descrição:** Este gráfico mostra a média de conversões semanais (SST-OPC) na carteira de restaurantes. As barras representam a média semanal de conversões registradas, com uma linha vermelha pontilhada indicando a média semanal. A projeção para a semana de 17 de junho é incluída com uma cor diferenciada.

# %%
df_data_weekly_sst = df_visao_carteira_conversoes[['SEMANA', 'SST-OPC']].copy()
df_data_weekly_sst['SST-OPC'] = df_data_weekly_sst['SST-OPC'].str.rstrip('%').astype('int64')
df_data_weekly_sst['SEMANA'] = pd.to_datetime(df_data_weekly_sst['SEMANA'], format='%Y-%m-%d')

weekly_data = df_data_weekly_sst.groupby('SEMANA')['SST-OPC'].mean().reset_index()

# Definir a semana de projeção e as quatro semanas anteriores
semana_projecao = '2024-06-17'
semanas_anteriores = pd.date_range(end=semana_projecao, periods=5, freq='W-MON')[:-1]

semanas_para_projecao = weekly_data[weekly_data['SEMANA'].isin(semanas_anteriores)]

if not semanas_para_projecao.empty:
    # Calcular a média das quatro semanas anteriores
    projection_value = semanas_para_projecao['SST-OPC'].mean()

    # Adicionar a projeção da semana
    projection_data = pd.DataFrame({'SEMANA': [semana_projecao + ' (Projeção)'], 'SST-OPC': [int(projection_value)]})
    weekly_data = pd.concat([weekly_data, projection_data], ignore_index=True)

    # Configurar o estilo do Seaborn
    sns.set()

    # Calcular a média semanal excluindo a projeção
    weekly_mean = weekly_data[weekly_data['SEMANA'] != semana_projecao + ' (Projeção)']['SST-OPC'].mean()

    def format_number(value):
        return f'{value:,.0f}%'.replace(',', 'X').replace('.', ',').replace('X', '.')

    # Adicionar a coluna de cores para diferenciar os dados reais da projeção
    weekly_data['color'] = ['Projeção' if x == semana_projecao + ' (Projeção)' else 'Real' for x in weekly_data['SEMANA']]

    # Plotar o gráfico
    plt.figure(figsize=(14, 7))
    sns.barplot(x='SEMANA', y='SST-OPC', data=weekly_data, hue='color', dodge=False, palette={'Projeção': 'grey', 'Real': '#4c72b0'})
    plt.axhline(weekly_mean, color='red', linestyle='--', label=f'Média: {format_number(weekly_mean)}')
    plt.title('Conversões Semanais na Carteira com Projeção para 17 de Junho', fontsize=16)
    plt.xlabel('Semana', fontsize=14)
    plt.ylabel('Média de Conversões na Vertical (SST-OPC)', fontsize=14)
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(plt.FixedFormatter(weekly_data['SEMANA'].apply(lambda x: x.strftime('%Y-%m-%d') if isinstance(x, pd.Timestamp) else x)))
    for index, row in weekly_data.iterrows():
        plt.text(index, row['SST-OPC'], format_number(row['SST-OPC']), color='black', ha="center", fontsize=12)
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), ncol=3)
    plt.tight_layout()
    plt.show()
else:
    print(f"As semanas anteriores a {semana_projecao} não estão presentes nos dados para calcular a projeção.")
# Out:
# <ipython-input-54-60af4531e696>:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().xaxis.set_major_formatter(plt.FixedFormatter(weekly_data['SEMANA'].apply(lambda x: x.strftime('%Y-%m-%d') if isinstance(x, pd.Timestamp) else x)))

# %%
# Conversões Mensais na Carteira com Projeção para Junho
df_data_month_sst = df_visao_carteira_conversoes[['SEMANA', 'SST-OPC']].copy()

df_data_month_sst['SST-OPC'] = df_data_month_sst['SST-OPC'].str.rstrip('%').astype('int64')
df_data_month_sst['SEMANA'] = pd.to_datetime(df_data_month_sst['SEMANA'], format='%Y-%m-%d')
df_data_month_sst['MES'] = df_data_month_sst['SEMANA'].dt.to_period('M')

monthly_data = df_data_month_sst.groupby('MES')['SST-OPC'].mean().reset_index()

meses_para_projecao = monthly_data[monthly_data['MES'].astype(str).isin(['2024-04', '2024-05'])]

if not meses_para_projecao.empty:
    # Calcular a média das conversões de Abril e Maio
    projection_june = meses_para_projecao['SST-OPC'].mean()

    # Adicionar a projeção de Junho aos dados mensais
    projection_data = pd.DataFrame({'MES': ['2024-06 (Projeção)'], 'SST-OPC': [int(projection_june)]})
    monthly_data = pd.concat([monthly_data, projection_data], ignore_index=True)

    # Configurar o estilo do Seaborn
    sns.set()

    # Calcular a média mensal excluindo a projeção
    monthly_mean = monthly_data[monthly_data['MES'] != '2024-06 (Projeção)']['SST-OPC'].mean()

    def format_number(value):
        return f'{value:,.0f}%'.replace(',', 'X').replace('.', ',').replace('X', '.')

    # Adicionar a coluna de cores para diferenciar os dados reais da projeção
    monthly_data['color'] = ['Projeção' if x == '2024-06 (Projeção)' else 'Real' for x in monthly_data['MES']]

    # Plotar o gráfico
    plt.figure(figsize=(14, 7))
    sns.barplot(x='MES', y='SST-OPC', data=monthly_data, hue='color', dodge=False, palette={'Projeção': 'grey', 'Real': '#4c72b0'})
    plt.axhline(monthly_mean, color='red', linestyle='--', label=f'Média: {format_number(monthly_mean)}')
    plt.title('Conversões Mensais na Carteira com Projeção para Junho', fontsize=16)
    plt.xlabel('Mês', fontsize=14)
    plt.ylabel('Média de Conversões na Vertical (SST-OPC)', fontsize=14)
    plt.xticks(rotation=45)
    for index, row in monthly_data.iterrows():
        plt.text(index, row['SST-OPC'], format_number(row['SST-OPC']), color='black', ha="center", fontsize=12)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print("Os meses 2024-04 e 2024-05 não estão presentes nos dados para calcular a projeção.")

# %% [markdown]
# ### Gráfico Usuario 1: Funil de Sessões Mensal
#
# - **Título:** Análise de Sessões Mensal do Usuário 1
# - **Descrição:** Este gráfico de funil ilustra a performance das sessões através das diferentes etapas do funil de vendas para para a segmentação usuario 1 ao longo dos meses. As etapas analisadas incluem Sessões na Vertical (SST), Sessões na Loja (SS), Sessões de Visualização de Produto (VPD), Sessões de Adição de Produto ao Carrinho (ATC), Sessões de Proceder ao Checkout (PTC), Sessões de Pedidos Solicitados (OP), e Sessões de Pedidos Confirmados (OPC). Cada ponto no gráfico representa o total acumulado para cada etapa, e os valores exibidos indicam tanto o total absoluto quanto a variação percentual em relação à etapa anterior, proporcionando uma visão clara das taxas de sessões e perdas em cada estágio do funil.

# %%
df_data_month_sst = df_sessoes_conversao_usuarios1

# Criar colunas adicionais para 'Mês'
df_data_month_sst['MES'] = df_data_month_sst['SEMANA'].dt.to_period('M')

# Agrupar os dados por mês e somar apenas as colunas numéricas relevantes
monthly_data = df_data_month_sst.groupby('MES')[['SST', 'SS', 'VPD', 'ATC', 'PTC', 'OP', 'OPC']].sum().reset_index()

sns.set()

# Função para formatar os números com pontos como separadores de milhar e vírgulas como separadores decimais
def format_number(value):
    return f'{value:,.0f}'.replace(',', 'X').replace('.', ',').replace('X', '.')

# Gráfico de Funil Mensal
fig, ax = plt.subplots(figsize=(16, 9))

for i, row in monthly_data.iterrows():
    funnel_values = [row['SST'], row['SS'], row['VPD'], row['ATC'], row['PTC'], row['OP'], row['OPC']]
    ax.plot([0, 1, 2, 3, 4, 5, 6], funnel_values, marker='o', label=str(row['MES']))
    for j, value in enumerate(funnel_values):
        if j > 0:
            percent_change = (funnel_values[j] - funnel_values[j-1]) / funnel_values[j-1] * 100
            ax.text(j, value, f"{format_number(value)} ({percent_change:.2f}%)", color='black', ha="center", fontsize=12)
        else:
            ax.text(j, value, format_number(value), color='black', ha="center", fontsize=12)

ax.set_xticks([0, 1, 2, 3, 4, 5, 6])
ax.set_xticklabels([
    'Sessões na Vertical\n(SST)',
    'Sessões na Loja\n(SS)',
    'Visualizações de Produto\n(VPD)',
    'Adições ao Carrinho\n(ATC)',
    'Proceder ao Checkout\n(PTC)',
    'Pedidos Solicitados\n(OP)',
    'Pedidos Confirmados\n(OPC)'
], rotation=0)
ax.set_title('Análise de Sessões Mensais do Usuário 1', fontsize=16)
ax.set_xlabel('Etapas', fontsize=14)
ax.set_ylabel('Total', fontsize=14)
ax.legend(title='Mês')
plt.tight_layout()
plt.show()

# %%
# Média e Mediana das Sessoes e Conversao: Usuarios 1

for column in df_sessoes_conversao_usuarios1.columns[8:]:
    df_sessoes_conversao_usuarios1[column] = df_sessoes_conversao_usuarios1[column].str.rstrip('%').astype(float)

mean_values_new_3 = df_sessoes_conversao_usuarios1.mean(numeric_only=True).round(2)
median_values_new_3 = df_sessoes_conversao_usuarios1.median(numeric_only=True).round(2)

# Criar um novo dataframe para as estatísticas com valores arredondados
stats_df_sessoes_conversao_usuarios1 = pd.DataFrame({
    'Estatística': ['Média', 'Mediana'],
    'SST': [mean_values_new_3['SST'].astype('int64'), median_values_new_3['SST'].astype('int64')],
    'SS': [mean_values_new_3['SS'].astype('int64'), median_values_new_3['SS'].astype('int64')],
    'VPD': [mean_values_new_3['VPD'].astype('int64'), median_values_new_3['VPD'].astype('int64')],
    'ATC': [mean_values_new_3['ATC'].astype('int64'), median_values_new_3['ATC'].astype('int64')],
    'PTC': [mean_values_new_3['PTC'].astype('int64'), median_values_new_3['PTC'].astype('int64')],
    'OP': [mean_values_new_3['OP'].astype('int64'), median_values_new_3['OP'].astype('int64')],
    'OPC': [mean_values_new_3['OPC'].astype('int64'), median_values_new_3['OPC'].astype('int64')],
    'SST-OPC': [f"{mean_values_new_3['SST-OPC']}%", f"{median_values_new_3['SST-OPC']}%"],
    'SST-SS': [f"{mean_values_new_3['SST-SS']}%", f"{median_values_new_3['SST-SS']}%"],
    'SS-VPD': [f"{mean_values_new_3['SS-VPD']}%", f"{median_values_new_3['SS-VPD']}%"],
    'SS-ATC': [f"{mean_values_new_3['SS-ATC']}%", f"{median_values_new_3['SS-ATC']}%"],
    'VPD-ATC': [f"{mean_values_new_3['VPD-ATC']}%", f"{median_values_new_3['VPD-ATC']}%"],
    'ATC-PTC': [f"{mean_values_new_3['ATC-PTC']}%", f"{median_values_new_3['ATC-PTC']}%"],
    'PTC-OP': [f"{mean_values_new_3['PTC-OP']}%", f"{median_values_new_3['PTC-OP']}%"],
    'OP-OPC': [f"{mean_values_new_3['OP-OPC']}%", f"{median_values_new_3['OP-OPC']}%"]
})

# Exibir o dataframe de estatísticas completas
stats_df_sessoes_conversao_usuarios1.head()
# Out:
#   Estatística     SST      SS     VPD     ATC    PTC     OP    OPC SST-OPC  \
# 0       Média  210946  179516  111787  104157  92080  77129  69101  32.91%
# 1     Mediana  211402  182915  112129  105024  92586  77520  69994   33.0%
#
#    SST-SS  SS-VPD SS-ATC VPD-ATC ATC-PTC  PTC-OP  OP-OPC
# 0  85.09%  62.27%  58.0%   93.0%  88.27%  83.91%  89.73%
# 1   85.0%   62.0%  58.0%   93.0%   88.0%   83.0%   90.0%

# %% [markdown]
# ### Gráfico Usuario 2: Funil de Sessões Mensal
#
# - **Título:** Análise de Sessões Mensal do Usuário 2
# - **Descrição:** Este gráfico de funil ilustra a performance das sessões através das diferentes etapas do funil de vendas para para a segmentação usuario 2 ao longo dos meses. As etapas analisadas incluem Sessões na Vertical (SST), Sessões na Loja (SS), Sessões de Visualização de Produto (VPD), Sessões de Adição de Produto ao Carrinho (ATC), Sessões de Proceder ao Checkout (PTC), Sessões de Pedidos Solicitados (OP), e Sessões de Pedidos Confirmados (OPC). Cada ponto no gráfico representa o total acumulado para cada etapa, e os valores exibidos indicam tanto o total absoluto quanto a variação percentual em relação à etapa anterior, proporcionando uma visão clara das taxas de sessões e perdas em cada estágio do funil.

# %%
df_data_month_sst = df_sessoes_conversao_usuarios2

# Criar colunas adicionais para 'Mês'
df_data_month_sst['MES'] = df_data_month_sst['SEMANA'].dt.to_period('M')

# Agrupar os dados por mês e somar apenas as colunas numéricas relevantes
monthly_data = df_data_month_sst.groupby('MES')[['SST', 'SS', 'VPD', 'ATC', 'PTC', 'OP', 'OPC']].sum().reset_index()

# Configurações do tema
sns.set()

# Função para formatar os números com pontos como separadores de milhar e vírgulas como separadores decimais
def format_number(value):
    return f'{value:,.0f}'.replace(',', 'X').replace('.', ',').replace('X', '.')

# Gráfico de Funil Mensal
fig, ax = plt.subplots(figsize=(16, 9))

for i, row in monthly_data.iterrows():
    funnel_values = [row['SST'], row['SS'], row['VPD'], row['ATC'], row['PTC'], row['OP'], row['OPC']]
    ax.plot([0, 1, 2, 3, 4, 5, 6], funnel_values, marker='o', label=str(row['MES']))
    for j, value in enumerate(funnel_values):
        if j > 0:
            percent_change = (funnel_values[j] - funnel_values[j-1]) / funnel_values[j-1] * 100
            ax.text(j, value, f"{format_number(value)} ({percent_change:.2f}%)", color='black', ha="center", fontsize=12)
        else:
            ax.text(j, value, format_number(value), color='black', ha="center", fontsize=12)

ax.set_xticks([0, 1, 2, 3, 4, 5, 6])
ax.set_xticklabels([
    'Sessões na Vertical\n(SST)',
    'Sessões na Loja\n(SS)',
    'Visualizações de Produto\n(VPD)',
    'Adições ao Carrinho\n(ATC)',
    'Proceder ao Checkout\n(PTC)',
    'Pedidos Solicitados\n(OP)',
    'Pedidos Confirmados\n(OPC)'
], rotation=0)
ax.set_title('Análise de Sessões Mensais do Usuário 2', fontsize=16)
ax.set_xlabel('Etapas', fontsize=14)
ax.set_ylabel('Total', fontsize=14)
ax.legend(title='Mês')
plt.tight_layout()
plt.show()

# %%
# Média e Mediana das Sessoes e Conversao: Usuarios 2

for column in df_sessoes_conversao_usuarios2.columns[8:]:
    df_sessoes_conversao_usuarios2[column] = df_sessoes_conversao_usuarios2[column].str.rstrip('%').astype(float)

mean_values_new_3 = df_sessoes_conversao_usuarios2.mean(numeric_only=True).round(2)
median_values_new_3 = df_sessoes_conversao_usuarios2.median(numeric_only=True).round(2)

stats_df_sessoes_conversao_usuarios2 = pd.DataFrame({
    'Estatística': ['Média', 'Mediana'],
    'SST': [mean_values_new_3['SST'].astype('int64'), median_values_new_3['SST'].astype('int64')],
    'SS': [mean_values_new_3['SS'].astype('int64'), median_values_new_3['SS'].astype('int64')],
    'VPD': [mean_values_new_3['VPD'].astype('int64'), median_values_new_3['VPD'].astype('int64')],
    'ATC': [mean_values_new_3['ATC'].astype('int64'), median_values_new_3['ATC'].astype('int64')],
    'PTC': [mean_values_new_3['PTC'].astype('int64'), median_values_new_3['PTC'].astype('int64')],
    'OP': [mean_values_new_3['OP'].astype('int64'), median_values_new_3['OP'].astype('int64')],
    'OPC': [mean_values_new_3['OPC'].astype('int64'), median_values_new_3['OPC'].astype('int64')],
    'SST-OPC': [f"{mean_values_new_3['SST-OPC']}%", f"{median_values_new_3['SST-OPC']}%"],
    'SST-SS': [f"{mean_values_new_3['SST-SS']}%", f"{median_values_new_3['SST-SS']}%"],
    'SS-VPD': [f"{mean_values_new_3['SS-VPD']}%", f"{median_values_new_3['SS-VPD']}%"],
    'SS-ATC': [f"{mean_values_new_3['SS-ATC']}%", f"{median_values_new_3['SS-ATC']}%"],
    'VPD-ATC': [f"{mean_values_new_3['VPD-ATC']}%", f"{median_values_new_3['VPD-ATC']}%"],
    'ATC-PTC': [f"{mean_values_new_3['ATC-PTC']}%", f"{median_values_new_3['ATC-PTC']}%"],
    'PTC-OP': [f"{mean_values_new_3['PTC-OP']}%", f"{median_values_new_3['PTC-OP']}%"],
    'OP-OPC': [f"{mean_values_new_3['OP-OPC']}%", f"{median_values_new_3['OP-OPC']}%"]
})

stats_df_sessoes_conversao_usuarios2.head()
# Out:
#   Estatística    SST     SS    VPD    ATC    PTC     OP   OPC SST-OPC SST-SS  \
# 0       Média  62430  47421  23460  23502  20191  13503  7396  11.91%  76.0%
# 1     Mediana  62317  47652  23671  23608  20207  13564  7460   12.0%  76.0%
#
#    SS-VPD  SS-ATC  VPD-ATC ATC-PTC  PTC-OP  OP-OPC
# 0  49.55%  49.55%  100.27%  85.82%  66.91%  54.82%
# 1   49.0%   49.0%   100.0%   86.0%   67.0%   56.0%

# %% [markdown]
# ### Comparação das Médias das Métricas de Sessões (Carteira e Vertical Restaurante)
#
# - **Título:** Comparação das Médias das Métricas de Sessões
# - **Descrição:** Este gráfico apresenta uma comparação das médias das principais métricas de sessões (SST, SS, VPD, ATC, PTC, OP, OPC) entre a carteira de restaurantes e a visão geral dos restaurantes. Ele permite visualizar e identificar quais áreas específicas da carteira de restaurantes podem estar com desempenho inferior em comparação com a média geral, ajudando na identificação de oportunidades para melhorias estratégicas e operacionais.
#
# O gráfico mostra a comparação das médias das métricas de sessões (SST, SS, VPD, ATC, PTC, OP, OPC) entre a carteira de restaurantes e a visão geral dos restaurantes. Aqui estão algumas observações:
#
# ## Análise:
#
# 1. **Sessões Totais (SST)**:
#    - A média das sessões totais é semelhante entre a carteira de restaurantes e a visão geral dos restaurantes.
#
# 2. **Sessões (SS)**:
#    - A média das sessões também é próxima para ambas as categorias, com uma leve vantagem para a visão geral dos restaurantes.
#
# 3. **Visualizações de Página de Produto (VPD)**:
#    - A visão geral dos restaurantes tem uma média de VPD um pouco maior que a carteira de restaurantes.
#
# 4. **Adicionar ao Carrinho (ATC)**:
#    - A média de ATC é levemente maior na visão geral dos restaurantes.
#
# 5. **Passar pelo Carrinho (PTC)**:
#    - A média de PTC é bastante similar entre as duas categorias, com uma leve vantagem para a visão geral.
#
# 6. **Ordem de Pedido (OP)**:
#    - A visão geral dos restaurantes tem uma média de OP um pouco maior.
#
# 7. **Ordem de Pedido Confirmada (OPC)**:
#    - A média de OPC é similar entre a carteira de restaurantes e a visão geral dos restaurantes.
#
# ### Insights:
# - As métricas de sessões são relativamente semelhantes entre a carteira de restaurantes e a visão geral dos restaurantes.
# - A visão geral dos restaurantes tende a ter médias levemente superiores em várias métricas, sugerindo que há espaço para melhorar as conversões na carteira de restaurantes.
#
# ### Recomendações:
# 1. **Foco em Melhorias de Conversão**:
#    - Implementar estratégias para melhorar as conversões na carteira de restaurantes, como otimização de UX/UI, ofertas promocionais e simplificação do processo de checkout.
#
# 2. **Monitoramento Contínuo**:
#    - Continuar monitorando essas métricas para identificar tendências e áreas de melhoria contínua.
#
# 3. **Colaboração com Parceiros**:
#    - Trabalhar em estreita colaboração com os restaurantes da carteira para entender e resolver problemas específicos que possam estar impactando as conversões.

# %%
carteira_sessoes_mean = df_visao_carteira_sessoes[['SST', 'SS', 'VPD', 'ATC', 'PTC', 'OP', 'OPC']].mean()
geral_sessoes_mean = df_visao_geral_restaurantes_sessoes[['SST', 'SS', 'VPD', 'ATC', 'PTC', 'OP', 'OPC']].mean()

# Criar um DataFrame para comparação
comparison_df = pd.DataFrame({
    'Métrica': carteira_sessoes_mean.index,
    'Carteira de Restaurantes': carteira_sessoes_mean.values,
    'Visão Geral dos Restaurantes': geral_sessoes_mean.values
}).set_index('Métrica')

# Configurações do tema
sns.set()

# Plotar o gráfico de comparação das médias das métricas de sessões
plt.figure(figsize=(18, 10))
ax = comparison_df.plot(kind='bar', figsize=(18, 10))
plt.title('Comparação das Médias das Métricas de Sessões')
plt.xlabel('Métricas de Sessões')
plt.ylabel('Média')
plt.xticks(rotation=45)

# Adicionar valores no gráfico
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() * 1.005, p.get_height() * 1.005))

plt.legend(loc='upper right')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### **Comparação das Médias das Taxas de Conversão (Carteira e Vertical Restaurante)**
#
# - **Título:** Comparação das Médias das Taxas de Conversão
# - **Descrição:** Este gráfico apresenta uma comparação das médias das principais taxas de conversão (SST-OPC, SST-SS, SS-VPD, SS-ATC, VPD-ATC, ATC-PTC, PTC-OP, OP-OPC) entre a carteira de restaurantes e a visão geral dos restaurantes. Ele permite visualizar e identificar quais áreas específicas da carteira de restaurantes podem estar com desempenho inferior em comparação com a média geral, ajudando na identificação de oportunidades para melhorias estratégicas e operacionais.

# %%
# Calcular as médias das taxas de conversão
carteira_conversoes_mean = df_visao_carteira_conversoes[['SST-OPC', 'SST-SS', 'SS-VPD', 'SS-ATC', 'VPD-ATC', 'ATC-PTC', 'PTC-OP', 'OP-OPC']].replace('%', '', regex=True).astype(float).mean()
geral_conversoes_mean = df_visao_geral_restaurantes_conversoes[['SST-OPC', 'SST-SS', 'SS-VPD', 'SS-ATC', 'VPD-ATC', 'ATC-PTC', 'PTC-OP', 'OP-OPC']].replace('%', '', regex=True).astype(float).mean()

# Criar um DataFrame para comparação
comparison_conversoes_df = pd.DataFrame({
    'Métrica': carteira_conversoes_mean.index,
    'Carteira de Restaurantes': carteira_conversoes_mean.values,
    'Visão Geral dos Restaurantes': geral_conversoes_mean.values
}).set_index('Métrica')

# Configurações do tema
sns.set()

# Plotar o gráfico de comparação das médias das taxas de conversão
plt.figure(figsize=(18, 10))
ax = comparison_conversoes_df.plot(kind='bar', figsize=(18, 10))
plt.title('Comparação das Médias das Taxas de Conversão')
plt.xlabel('Métricas de Conversão')
plt.ylabel('Taxa de Conversão (%)')
plt.xticks(rotation=45)

# Adicionar valores no gráfico
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() * 1.005, p.get_height() * 1.005))

plt.legend(loc='upper right')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### **Comparação de Disponibilidade de Lojas entre Vertical Restaurante e Carteira**
#
# - **Título:** Comparação de Disponibilidade de Lojas entre Vertical Restaurante e Carteira
# - **Descrição:** Este gráfico apresenta uma comparação da disponibilidade das lojas entre a vertical de restaurantes e a carteira de restaurantes ao longo de várias semanas. As linhas contínuas representam os valores de disponibilidade para cada categoria, enquanto a linha tracejada mostra a diferença percentual entre a carteira de restaurantes e a visão geral dos restaurantes. Ele ajuda a visualizar como a disponibilidade das lojas varia ao longo do tempo e a identificar possíveis discrepâncias que possam impactar o desempenho operacional.
#
#
# #### Tabela de Comparação da Disponibilidade das Lojas
#
# | Semana    | Carteira de Restaurantes (%) | Visão Geral dos Restaurantes (%) | Diferença (%) |
# |-----------|------------------------------|----------------------------------|---------------|
# | 2024-04-01| 98.00                        | 90.00                            | 8.00          |
# | 2024-04-08| 98.00                        | 89.00                            | 9.00          |
# | 2024-04-15| 98.00                        | 89.00                            | 9.00          |
# | 2024-04-22| 98.00                        | 87.00                            | 11.00         |
# | 2024-05-01| 98.00                        | 86.00                            | 12.00         |
# | 2024-05-08| 98.00                        | 86.00                            | 12.00         |
# | 2024-05-15| 98.00                        | 90.00                            | 8.00          |
# | 2024-05-22| 98.00                        | 90.00                            | 8.00          |
# | 2024-06-01| 98.00                        | 91.00                            | 7.00          |
# | 2024-06-08| 98.00                        | 92.00                            | 6.00          |
#
#
# #### **Análise de Disponibilidade de Lojas**
#
# ### Observações e Insights
#
# 1. **Disponibilidade Consistentemente Alta para Carteira de Restaurantes**:
#    - A disponibilidade de lojas na carteira de restaurantes é consistentemente alta, mantendo-se em torno de 98% ao longo das semanas analisadas. Isso indica que as lojas da carteira estão geralmente disponíveis e prontas para atender pedidos.
#
# 2. **Variabilidade na Disponibilidade para a Visão Geral dos Restaurantes**:
#    - A disponibilidade de lojas na visão geral dos restaurantes mostra mais variabilidade, com valores variando entre 86% e 92%. Isso sugere que algumas lojas fora da carteira podem enfrentar mais desafios em termos de disponibilidade.
#
# 3. **Diferença Entre Carteira e Visão Geral**:
#    - A diferença entre a disponibilidade de lojas na carteira e na visão geral dos restaurantes varia entre 6% e 12%. Essa diferença indica que a carteira de restaurantes tende a ter uma disponibilidade superior, o que pode ser um ponto de destaque e vantagem competitiva.
#
#
# ### Conclusão
#
# A análise mostra que a carteira de restaurantes tem uma disponibilidade de lojas consistentemente alta, enquanto a visão geral dos restaurantes apresenta mais variabilidade.

# %%
carteira_store_avail = df_visao_carteira_conversoes[['SEMANA', 'STORE_AVAILABILITY']].replace('%', '', regex=True).astype({'STORE_AVAILABILITY': float})
geral_store_avail = df_visao_geral_restaurantes_conversoes[['SEMANA', 'STORE_AVAILABILITY']].replace('%', '', regex=True).astype({'STORE_AVAILABILITY': float})

# Calcular a diferença
store_avail_diff = carteira_store_avail.copy()
store_avail_diff['STORE_AVAILABILITY_DIFF'] = carteira_store_avail['STORE_AVAILABILITY'] - geral_store_avail['STORE_AVAILABILITY']

# Configurações do tema
sns.set()

# Plotar o gráfico de linhas
plt.figure(figsize=(18, 10))
plt.plot(carteira_store_avail['SEMANA'], carteira_store_avail['STORE_AVAILABILITY'], label='Carteira de Restaurantes', marker='o')
plt.plot(geral_store_avail['SEMANA'], geral_store_avail['STORE_AVAILABILITY'], label='Visão Geral dos Restaurantes', marker='o')
plt.plot(store_avail_diff['SEMANA'], store_avail_diff['STORE_AVAILABILITY_DIFF'], label='Diferença', linestyle='--', marker='o')
plt.title('Comparação da Disponibilidade das Lojas entre Vertical Restaurante e Carteira')
plt.xlabel('Semana')
plt.ylabel('Disponibilidade das Lojas (%)')
plt.xticks(rotation=45)
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=3)  # Ajustar a localização da legenda
plt.tight_layout()

# Adicionar valores no gráfico
for x, y in zip(carteira_store_avail['SEMANA'], carteira_store_avail['STORE_AVAILABILITY']):
    plt.text(x, y, f'{y:.2f}%', ha='right', va='bottom')
for x, y in zip(geral_store_avail['SEMANA'], geral_store_avail['STORE_AVAILABILITY']):
    plt.text(x, y, f'{y:.2f}%', ha='right', va='bottom')
for x, y in zip(store_avail_diff['SEMANA'], store_avail_diff['STORE_AVAILABILITY_DIFF']):
    plt.text(x, y, f'{y:.2f}%', ha='right', va='bottom')

plt.show()

# %% [markdown]
# ### Comparação de Disponibilidade de Produto entre Vertical Restaurante e Carteira
#
# - **Título:** Comparação de Disponibilidade de Produto entre Vertical Restaurante e Carteira
# - **Descrição:** Este gráfico apresenta uma comparação da disponibilidade de produtos entre a vertical de restaurantes e a carteira de restaurantes ao longo de várias semanas. As linhas contínuas representam os valores de disponibilidade de produtos para cada categoria, enquanto a linha tracejada mostra a diferença percentual entre a carteira de restaurantes e a visão geral dos restaurantes. Ele ajuda a visualizar como a disponibilidade de produtos varia ao longo do tempo e a identificar possíveis discrepâncias que possam impactar o desempenho operacional.
#
# | Semana    | Carteira de Restaurantes (%) | Visão Geral dos Restaurantes (%) | Diferença (%) |
# |-----------|-------------------------------|----------------------------------|---------------|
# | 4/1/2024  | 87.0                          | 85.0                             | 2.0           |
# | 4/8/2024  | 87.0                          | 91.0                             | -4.0          |
# | 4/15/2024 | 82.0                          | 88.0                             | -6.0          |
# | 4/22/2024 | 87.0                          | 88.0                             | -1.0          |
# | 4/29/2024 | 87.0                          | 86.0                             | 1.0           |
# | 5/6/2024  | 82.0                          | 86.0                             | -4.0          |
# | 5/13/2024 | 85.0                          | 85.0                             | 0.0           |
# | 5/20/2024 | 82.0                          | 82.0                             | 0.0           |
# | 5/27/2024 | 90.0                          | 90.0                             | 0.0           |
# | 6/3/2024  | 90.0                          | 90.0                             | 0.0           |
# | 6/10/2024 | 90.0                          | 90.0                             | 0.0           |
#
# ### Análise de Disponibilidade de Produtos
#
# #### Observações e Insights
#
# 1. **Disponibilidade de Produtos na Carteira de Restaurantes**:
#    - A disponibilidade de produtos na carteira de restaurantes varia entre 82% e 91% ao longo das semanas analisadas. Isso indica que há certa variabilidade, mas a disponibilidade é relativamente alta na maioria das semanas.
#
# 2. **Disponibilidade de Produtos na Visão Geral dos Restaurantes**:
#    - A disponibilidade de produtos na visão geral dos restaurantes varia entre 82% e 90%. Embora semelhante à carteira, há algumas semanas em que a disponibilidade é ligeiramente menor.
#
# 3. **Diferença Entre Carteira e Visão Geral**:
#    - A diferença entre a disponibilidade de produtos na carteira e na visão geral dos restaurantes varia entre -6% e 2%. Uma diferença negativa indica que a visão geral dos restaurantes tem uma disponibilidade ligeiramente maior em algumas semanas.
#
# 4. **Pontos de Atenção**:
#    - Semanas com maior diferença negativa: As semanas de 04/08/2024, 04/15/2024, e 05/06/2024 mostram uma diferença negativa de até -6%, indicando que a disponibilidade de produtos na visão geral é maior nessas semanas.
#    - Semanas com menor diferença: As semanas de 04/01/2024 e 04/22/2024 apresentam uma diferença positiva de 2% e 1%, respectivamente, sugerindo que a carteira de restaurantes tem uma disponibilidade ligeiramente melhor nessas semanas.
#
# ### Recomendações
#
# 1. **Monitoramento Contínuo**:
#    - Continuar monitorando a disponibilidade de produtos tanto na carteira quanto na visão geral para identificar rapidamente quaisquer quedas na disponibilidade e tomar ações corretivas.
#
# 2. **Apoio Adicional para Lojas Fora da Carteira**:
#    - Fornecer suporte adicional para as lojas fora da carteira para melhorar sua disponibilidade de produtos. Isso pode incluir treinamento, recursos adicionais ou melhorias tecnológicas.
#
# 3. **Análise de Causas Raiz**:
#    - Realizar uma análise detalhada das causas raiz para a variabilidade na disponibilidade de produtos fora da carteira. Identificar se há fatores específicos que podem ser abordados para melhorar a disponibilidade.
#
# 4. **Compartilhamento de Melhores Práticas**:
#    - Compartilhar as melhores práticas das lojas da carteira com as lojas fora da carteira para ajudar a elevar o nível geral de disponibilidade.
#
# ### Conclusão
#
# A análise mostra que a disponibilidade de produtos na carteira de restaurantes é geralmente alta, mas apresenta variabilidade semelhante à visão geral dos restaurantes. Abordar as causas da variabilidade na disponibilidade de produtos pode ajudar a melhorar a eficiência operacional e a satisfação do cliente.

# %%
carteira_product_avail = df_visao_carteira_conversoes[['SEMANA', 'PRODUCT_AVAILABILITY']].replace('%', '', regex=True).astype({'PRODUCT_AVAILABILITY': float})
geral_product_avail = df_visao_geral_restaurantes_conversoes[['SEMANA', 'PRODUCT_AVAILABILITY']].replace('%', '', regex=True).astype({'PRODUCT_AVAILABILITY': float})

# Calcular a diferença
product_avail_diff = carteira_product_avail.copy()
product_avail_diff['PRODUCT_AVAILABILITY_DIFF'] = carteira_product_avail['PRODUCT_AVAILABILITY'] - geral_product_avail['PRODUCT_AVAILABILITY']

# Configurações do tema
sns.set()

# Plotar o gráfico de linhas
plt.figure(figsize=(18, 10))
plt.plot(carteira_product_avail['SEMANA'], carteira_product_avail['PRODUCT_AVAILABILITY'], label='Carteira de Restaurantes', marker='o')
plt.plot(geral_product_avail['SEMANA'], geral_product_avail['PRODUCT_AVAILABILITY'], label='Visão Geral dos Restaurantes', marker='o')
plt.plot(product_avail_diff['SEMANA'], product_avail_diff['PRODUCT_AVAILABILITY_DIFF'], label='Diferença', linestyle='--', marker='o')
plt.title('Comparação de Disponibilidade de Produto entre Vertical Restaurante e Carteira')
plt.xlabel('Semana')
plt.ylabel('Disponibilidade de Produto (%)')
plt.xticks(rotation=45)
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=3)
plt.tight_layout()

# Adicionar valores no gráfico
for x, y in zip(carteira_product_avail['SEMANA'], carteira_product_avail['PRODUCT_AVAILABILITY']):
    plt.text(x, y, f'{y:.2f}%', ha='right', va='bottom')
for x, y in zip(geral_product_avail['SEMANA'], geral_product_avail['PRODUCT_AVAILABILITY']):
    plt.text(x, y, f'{y:.2f}%', ha='right', va='bottom')
for x, y in zip(product_avail_diff['SEMANA'], product_avail_diff['PRODUCT_AVAILABILITY_DIFF']):
    plt.text(x, y, f'{y:.2f}%', ha='right', va='bottom')

plt.show()

# %% [markdown]
# # **Caso aumentarmos a dispobilidade dos produtos, quanto projetivo de conversão teremos?**
#
# Para projetar o aumento na conversão com base na melhoria da disponibilidade de produtos, podemos utilizar uma análise de regressão ou calcular a elasticidade da conversão em relação à disponibilidade de produtos. Vamos supor que temos uma relação linear entre a disponibilidade de produtos e a conversão.
#
# ### Passos:
#
# 1. **Reunir dados históricos de conversão e disponibilidade de produtos**.
# 2. **Calcular a relação entre disponibilidade de produtos e taxa de conversão usando uma regressão linear**.
# 3. **Projetar a conversão futura com base no aumento da disponibilidade de produtos**.
#
# ### Supondo os seguintes dados (exemplo simplificado):
#
# - **Disponibilidade de produtos**: Percentual de disponibilidade de produtos.
# - **Taxa de conversão**: Percentual de conversão de sessões em pedidos confirmados (OPC).
#
# Vou usar dados de exemplo simplificados para ilustrar esse processo.
#
# ### Código Python para Projeção
#
# ```python
# import pandas as pd
# import numpy as np
# import statsmodels.api as sm
#
# # Exemplo de dados históricos simplificados
# data = {
#     'PRODUCT_AVAILABILITY': [85, 87, 88, 89, 90, 92, 94, 95, 96, 98],
#     'CONVERSION_RATE': [10, 12, 14, 15, 16, 17, 19, 20, 21, 23]  # Percentual de conversão (OPC)
# }
#
# df = pd.DataFrame(data)
#
# # Regressão linear
# X = df['PRODUCT_AVAILABILITY']
# y = df['CONVERSION_RATE']
# X = sm.add_constant(X)  # Adicionar constante para a regressão
# model = sm.OLS(y, X).fit()
#
# # Resumo do modelo
# print(model.summary())
#
# # Projeção de aumento na disponibilidade de produtos
# future_availability = np.array([99, 100])  # Exemplos de disponibilidade futura
# future_availability = sm.add_constant(future_availability)  # Adicionar constante
# predicted_conversion = model.predict(future_availability)
#
# # Resultados projetados
# predicted_conversion
# ```
#
# ### Análise dos Resultados
#
# O modelo de regressão linear fornecerá uma estimativa da relação entre a disponibilidade de produtos e a taxa de conversão. Com base nessa relação, podemos projetar a taxa de conversão para diferentes níveis futuros de disponibilidade de produtos.
#
# ### Exemplo de Interpretação
#
# Se a regressão linear indicar que um aumento de 1% na disponibilidade de produtos resulta em um aumento de 0.5% na taxa de conversão, e aumentarmos a disponibilidade de produtos de 90% para 95%, podemos esperar um aumento de 2.5% na taxa de conversão.
#
# Vamos calcular isso com os dados de exemplo.
#
# ```python
# import pandas as pd
# import numpy as np
# import statsmodels.api as sm
#
# # Carregar os dados do arquivo visao_carteira_conversoes.csv
# visao_carteira_conversoes_df = pd.read_csv('/mnt/data/visao_carteira_conversoes.csv')
#
# # Selecionar as colunas necessárias
# product_avail_data = visao_carteira_conversoes_df[['PRODUCT_AVAILABILITY', 'SST-OPC']].replace('%', '', regex=True).astype(float)
#
# # Renomear as colunas para facilitar a análise
# product_avail_data.columns = ['PRODUCT_AVAILABILITY', 'CONVERSION_RATE']
#
# # Regressão linear
# X = product_avail_data['PRODUCT_AVAILABILITY']
# y = product_avail_data['CONVERSION_RATE']
# X = sm.add_constant(X)  # Adicionar constante para a regressão
# model = sm.OLS(y, X).fit()
#
# # Resumo do modelo
# model_summary = model.summary()
#
# # Projeção de aumento na disponibilidade de produtos para 95%
# future_availability = np.array([[1, 95]])  # Disponibilidade futura com constante
# predicted_conversion = model.predict(future_availability)
#
# model_summary, predicted_conversion
# ```
# ### Resultados da Análise de Regressão Linear
#
# O modelo de regressão linear mostra a seguinte relação entre a disponibilidade de produtos e a taxa de conversão:
#
# - **Intercepto (const)**: -2.9229
# - **Coeficiente de Disponibilidade de Produtos**: 0.2278
#
# #### Projeção de Conversão para 95% de Disponibilidade de Produtos
#
# - **Projeção de Conversão**: Aproximadamente 18.72%
#
# ### Interpretação dos Resultados
#
# 1. **R-squared**: O valor de R-squared é 0.286, indicando que aproximadamente 28.6% da variação na taxa de conversão pode ser explicada pela disponibilidade de produtos. Isso sugere que outros fatores também influenciam a taxa de conversão.
# 2. **Coeficiente de Disponibilidade de Produtos**: O coeficiente de 0.2278 indica que para cada aumento de 1% na disponibilidade de produtos, a taxa de conversão aumenta em aproximadamente 0.2278%.
#
# ### Significância do Modelo
#
# - **P-valor do Coeficiente**: O p-valor de 0.090 sugere que a relação entre a disponibilidade de produtos e a taxa de conversão é marginalmente significativa ao nível de 10%, mas não ao nível de 5%.
#
# ### Conclusão
#
# Aumentar a disponibilidade de produtos para 95% pode ter um impacto positivo na taxa de conversão, aumentando-a para aproximadamente 18.72%. No entanto, a significância estatística do modelo indica que outros fatores também devem ser considerados para explicar a variação na taxa de conversão.

# %% [markdown]
# ### **Comparação das Taxas de Conversão Entre Usuários 1, 2 e a Vertical de Restaurantes Geral**
#
# - **Título:** Comparação das Taxas de Conversão Entre Usuários 1, 2 e a Vertical de Restaurantes Geral
# - **Descrição:** Este gráfico apresenta uma comparação das taxas de conversão em diferentes etapas do funil de conversão (SST-OPC, SST-SS, SS-VPD, SS-ATC, VPD-ATC, ATC-PTC, PTC-OP, OP-OPC) entre os Usuários 1, 2 e a Vertical de Restaurantes Geral. As barras indicam a taxa de conversão percentual para cada métrica, permitindo identificar rapidamente onde cada usuário está se saindo melhor ou pior. Isso pode ajudar a orientar estratégias de melhoria focadas nas áreas com desempenho inferior, especialmente para o Usuário 2, que apresenta taxas de conversão consistentemente mais baixas.
#
# ### Conclusões sobre o Desempenho dos Usuários 1, 2 e a Vertical de Restaurantes
#
# 1. **Usuário 1**:
#    - **Desempenho Superior**: O Usuário 1 tem melhores taxas de conversão em comparação com a vertical de restaurantes geral em várias etapas do funil de conversão.
#
# 2. **Usuário 2**:
#    - **Desempenho Inferior**: O Usuário 2 apresenta taxas de conversão menores em comparação com a vertical de restaurantes geral em várias etapas do funil de conversão.
#
# 3. **Vertical de Restaurantes Geral**:
#    - **Benchmark**: A vertical de restaurantes geral serve como um benchmark para identificar onde os Usuários 1 e 2 podem melhorar.
#
# ### Propostas de Ações para Melhorar as Métricas de Conversão
#
# 1. **Melhorar a Experiência de Navegação (SS-VPD)**:
#    - **Usuário 2**: Realizar análises UX/UI para identificar pontos de fricção e melhorar a navegação no site/app.
#    - **Ações**: Implementar testes A/B para diferentes layouts de página e verificar quais aumentam a taxa de visualizações de produtos.
#
# 2. **Aumentar a Taxa de Adição ao Carrinho (SS-ATC)**:
#    - **Promoções e Incentivos**: Oferecer promoções direcionadas e incentivos para adicionar produtos ao carrinho.
#    - **Interface Intuitiva**: Simplificar a interface de adição ao carrinho e destacar produtos recomendados.
#
# 3. **Simplificar o Processo de Checkout (PTC-OP)**:
#    - **Usuário 2**: Focar na simplificação do processo de checkout, reduzindo etapas desnecessárias.
#    - **Ações**: Implementar opções de pagamento rápidas e seguras, além de facilitar a edição do carrinho durante o checkout.
#
# 4. **Acompanhamento Contínuo e Feedback**:
#    - **Monitoramento**: Estabelecer um sistema de monitoramento contínuo para acompanhar métricas e identificar rapidamente quedas de desempenho.
#    - **Feedback dos Usuários**: Coletar feedback regular dos usuários para entender suas dificuldades e ajustar as estratégias conforme necessário.
#
# ### Conclusão
#
# Melhorar as métricas de conversão requer uma abordagem multifacetada que aborde a experiência do usuário, promoções, simplificação de processos e monitoramento contínuo. Com base na análise comparativa, tanto os Usuários 1 e 2 quanto a vertical de restaurantes geral podem se beneficiar de estratégias de melhoria focadas nas áreas com desempenho inferior.

# %%
# Configurações do tema
sns.set()

# Calcular as médias das taxas de conversão
conversion_metrics_1 = df_sessoes_conversao_usuarios1[['SST-OPC', 'SST-SS', 'SS-VPD', 'SS-ATC', 'VPD-ATC', 'ATC-PTC', 'PTC-OP', 'OP-OPC']].replace('%', '', regex=True).astype(float).mean()
conversion_metrics_2 = df_sessoes_conversao_usuarios2[['SST-OPC', 'SST-SS', 'SS-VPD', 'SS-ATC', 'VPD-ATC', 'ATC-PTC', 'PTC-OP', 'OP-OPC']].replace('%', '', regex=True).astype(float).mean()
conversion_metrics_general = df_visao_geral_restaurantes_conversoes[['SST-OPC', 'SST-SS', 'SS-VPD', 'SS-ATC', 'VPD-ATC', 'ATC-PTC', 'PTC-OP', 'OP-OPC']].replace('%', '', regex=True).astype(float).mean()

# Comparar as métricas de conversão entre os usuários e a vertical de restaurantes geral
conversion_comparison_df = pd.DataFrame({
    'Métrica': conversion_metrics_1.index,
    'Usuário 1 (%)': conversion_metrics_1.values,
    'Usuário 2 (%)': conversion_metrics_2.values,
    'Vertical de Restaurantes (%)': conversion_metrics_general.values
}).set_index('Métrica')

# Plotar as métricas de conversão
plt.figure(figsize=(18, 10))
ax = conversion_comparison_df.plot(kind='bar', figsize=(18, 10))
plt.title('Comparação das Taxas de Conversão Entre Usuários 1, 2 e a Vertical de Restaurantes')
plt.xlabel('Métricas de Conversão')
plt.ylabel('Taxa de Conversão (%)')
plt.xticks(rotation=45)

# Adicionar valores no gráfico
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() * 1.005, p.get_height() * 1.005))

plt.legend(loc='upper right')
plt.tight_layout()

plt.show()
